# %%
import pandas as pd

# %%
m1=pd.read_csv("mtcars.csv")

# %%
m1
# Out:
#      mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  carb
# 0   21.0    6  160.0  110  3.90  2.620  16.46   0   1     4     4
# 1   21.0    6  160.0  110  3.90  2.875  17.02   0   1     4     4
# 2   22.8    4  108.0   93  3.85  2.320  18.61   1   1     4     1
# 3   21.4    6  258.0  110  3.08  3.215  19.44   1   0     3     1
# 4   18.7    8  360.0  175  3.15  3.440  17.02   0   0     3     2
# 5   18.1    6  225.0  105  2.76  3.460  20.22   1   0     3     1
# 6   14.3    8  360.0  245  3.21  3.570  15.84   0   0     3     4
# 7   24.4    4  146.7   62  3.69  3.190  20.00   1   0     4     2
# 8   22.8    4  140.8   95  3.92  3.150  22.90   1   0     4     2
# 9   19.2    6  167.6  123  3.92  3.440  18.30   1   0     4     4
# 10  17.8    6  167.6  123  3.92  3.440  18.90   1   0     4     4
# 11  16.4    8  275.8  180  3.07  4.070  17.40   0   0     3     3
# 12  17.3    8  275.8  180  3.07  3.730  17.60   0   0     3     3
# ...

# %%
# uniariate profiling
# data summarization
m1['mpg'].describe()
# Out:
# count    32.000000
# mean     20.090625
# std       6.026948
# min      10.400000
# 25%      15.425000
# 50%      19.200000
# 75%      22.800000
# max      33.900000
# Name: mpg, dtype: float64

# %%
m1['mpg'].plot.box()
# Out:
# <AxesSubplot:>

# %%
m1['wt'].describe()
# Out:
# count    32.000000
# mean      3.217250
# std       0.978457
# min       1.513000
# 25%       2.581250
# 50%       3.325000
# 75%       3.610000
# max       5.424000
# Name: wt, dtype: float64

# %%
m1['wt'].plot.box()
# Out:
# <AxesSubplot:>

# %%
m1.corr()
# Out:
#            mpg       cyl      disp        hp      drat        wt      qsec  \
# mpg   1.000000 -0.852162 -0.847551 -0.776168  0.681172 -0.867659  0.418684
# cyl  -0.852162  1.000000  0.902033  0.832447 -0.699938  0.782496 -0.591242
# disp -0.847551  0.902033  1.000000  0.790949 -0.710214  0.887980 -0.433698
# hp   -0.776168  0.832447  0.790949  1.000000 -0.448759  0.658748 -0.708223
# drat  0.681172 -0.699938 -0.710214 -0.448759  1.000000 -0.712441  0.091205
# wt   -0.867659  0.782496  0.887980  0.658748 -0.712441  1.000000 -0.174716
# qsec  0.418684 -0.591242 -0.433698 -0.708223  0.091205 -0.174716  1.000000
# vs    0.664039 -0.810812 -0.710416 -0.723097  0.440278 -0.554916  0.744535
# am    0.599832 -0.522607 -0.591227 -0.243204  0.712711 -0.692495 -0.229861
# gear  0.480285 -0.492687 -0.555569 -0.125704  0.699610 -0.583287 -0.212682
# carb -0.550925  0.526988  0.394977  0.749812 -0.090790  0.427606 -0.656249
#
#             vs        am      gear      carb
# ...

# %%
m1['mpg'].corr(m1['disp'])
# Out:
# -0.8475513792624785

# %%
m1.plot.scatter("mpg",'disp')
# Out:
# <AxesSubplot:xlabel='mpg', ylabel='disp'>

# %%
import numpy as np
import statsmodels.formula.api as smapi

# %%
model=smapi.ols(formula='mpg~ wt',data=m1).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    mpg   R-squared:                       0.753
# Model:                            OLS   Adj. R-squared:                  0.745
# Method:                 Least Squares   F-statistic:                     91.38
# Date:                Mon, 10 Apr 2023   Prob (F-statistic):           1.29e-10
# Time:                        14:32:09   Log-Likelihood:                -80.015
# No. Observations:                  32   AIC:                             164.0
# Df Residuals:                      30   BIC:                             167.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     37.2851      1.878     19.858      0.000      33.450      41.120
# ...

# %%
m1['mpg'].describe()
# Out:
# count    32.000000
# mean     20.090625
# std       6.026948
# min      10.400000
# 25%      15.425000
# 50%      19.200000
# 75%      22.800000
# max      33.900000
# Name: mpg, dtype: float64

# %%
m1['mpg'].plot.box()
# Out:
# <AxesSubplot:>

# %%
m1.corr()
# Out:
#            mpg       cyl      disp        hp      drat        wt      qsec  \
# mpg   1.000000 -0.852162 -0.847551 -0.776168  0.681172 -0.867659  0.418684
# cyl  -0.852162  1.000000  0.902033  0.832447 -0.699938  0.782496 -0.591242
# disp -0.847551  0.902033  1.000000  0.790949 -0.710214  0.887980 -0.433698
# hp   -0.776168  0.832447  0.790949  1.000000 -0.448759  0.658748 -0.708223
# drat  0.681172 -0.699938 -0.710214 -0.448759  1.000000 -0.712441  0.091205
# wt   -0.867659  0.782496  0.887980  0.658748 -0.712441  1.000000 -0.174716
# qsec  0.418684 -0.591242 -0.433698 -0.708223  0.091205 -0.174716  1.000000
# vs    0.664039 -0.810812 -0.710416 -0.723097  0.440278 -0.554916  0.744535
# am    0.599832 -0.522607 -0.591227 -0.243204  0.712711 -0.692495 -0.229861
# gear  0.480285 -0.492687 -0.555569 -0.125704  0.699610 -0.583287 -0.212682
# carb -0.550925  0.526988  0.394977  0.749812 -0.090790  0.427606 -0.656249
#
#             vs        am      gear      carb
# ...

# %%
m1['mpg'].corr(m1['disp'])
# Out:
# -0.8475513792624785

# %%
m1.plot.scatter('mpg','disp')
# Out:
# <AxesSubplot:xlabel='mpg', ylabel='disp'>

# %%
import matplotlib.pyplot as plt

# %%
import statsmodels.formula.api as smapi

# %%
model1=smapi.ols(formula=' mpg ~ disp',data=m1).fit()

# %%
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    mpg   R-squared:                       0.753
# Model:                            OLS   Adj. R-squared:                  0.745
# Method:                 Least Squares   F-statistic:                     91.38
# Date:                Mon, 10 Apr 2023   Prob (F-statistic):           1.29e-10
# Time:                        14:32:10   Log-Likelihood:                -80.015
# No. Observations:                  32   AIC:                             164.0
# Df Residuals:                      30   BIC:                             167.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     37.2851      1.878     19.858      0.000      33.450      41.120
# ...

# %%
prediction=model1.predict()
prediction
# Out:
# array([23.00543556, 23.00543556, 25.1486218 , 18.96635381, 14.76241157,
#        20.32645276, 14.76241157, 23.55359666, 23.79676587, 22.69220065,
#        22.69220065, 18.23272467, 18.23272467, 18.23272467, 10.14631813,
#        10.64089957, 11.46520197, 26.35622482, 26.47987017, 26.66945973,
#        24.64991885, 16.49344661, 17.07045829, 15.17456277, 13.11380677,
#        26.34386028, 24.64167582, 25.68029685, 15.13334765, 23.62366236,
#        17.19410365, 24.61282524])

# %%
m1['pred']=prediction

# %%
m1
# Out:
#      mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  carb       pred
# 0   21.0    6  160.0  110  3.90  2.620  16.46   0   1     4     4  23.005436
# 1   21.0    6  160.0  110  3.90  2.875  17.02   0   1     4     4  23.005436
# 2   22.8    4  108.0   93  3.85  2.320  18.61   1   1     4     1  25.148622
# 3   21.4    6  258.0  110  3.08  3.215  19.44   1   0     3     1  18.966354
# 4   18.7    8  360.0  175  3.15  3.440  17.02   0   0     3     2  14.762412
# 5   18.1    6  225.0  105  2.76  3.460  20.22   1   0     3     1  20.326453
# 6   14.3    8  360.0  245  3.21  3.570  15.84   0   0     3     4  14.762412
# 7   24.4    4  146.7   62  3.69  3.190  20.00   1   0     4     2  23.553597
# 8   22.8    4  140.8   95  3.92  3.150  22.90   1   0     4     2  23.796766
# 9   19.2    6  167.6  123  3.92  3.440  18.30   1   0     4     4  22.692201
# 10  17.8    6  167.6  123  3.92  3.440  18.90   1   0     4     4  22.692201
# ...

# %%
plt.figure(figsize=(8,6))
plt.plot(m1['disp'],m1['mpg'],'o')
plt.plot(m1['disp'],prediction,'r')
plt.xlabel('wt')
plt.ylabel('mpg')
plt.title('MPG VS WT')
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.formula.api as smapi

# %%
mt=pd.read_csv('mtcars.csv')
lung=pd.read_csv('LungCap.csv')

# %%
mt.corr()
# Out:
#            mpg       cyl      disp        hp      drat        wt      qsec  \
# mpg   1.000000 -0.852162 -0.847551 -0.776168  0.681172 -0.867659  0.418684
# cyl  -0.852162  1.000000  0.902033  0.832447 -0.699938  0.782496 -0.591242
# disp -0.847551  0.902033  1.000000  0.790949 -0.710214  0.887980 -0.433698
# hp   -0.776168  0.832447  0.790949  1.000000 -0.448759  0.658748 -0.708223
# drat  0.681172 -0.699938 -0.710214 -0.448759  1.000000 -0.712441  0.091205
# wt   -0.867659  0.782496  0.887980  0.658748 -0.712441  1.000000 -0.174716
# qsec  0.418684 -0.591242 -0.433698 -0.708223  0.091205 -0.174716  1.000000
# vs    0.664039 -0.810812 -0.710416 -0.723097  0.440278 -0.554916  0.744535
# am    0.599832 -0.522607 -0.591227 -0.243204  0.712711 -0.692495 -0.229861
# gear  0.480285 -0.492687 -0.555569 -0.125704  0.699610 -0.583287 -0.212682
# carb -0.550925  0.526988  0.394977  0.749812 -0.090790  0.427606 -0.656249
#
#             vs        am      gear      carb
# ...

# %%
mt['mpg'].corr(mt['wt'])
# Out:
# -0.8676593765172281

# %%
mt.plot.scatter("mpg",'wt')
# Out:
# <AxesSubplot:xlabel='mpg', ylabel='wt'>

# %%
sns.regplot(x='mpg',y='wt',data=mt)
# Out:
# <AxesSubplot:xlabel='mpg', ylabel='wt'>

# %%
model2=smapi.ols(formula='mpg ~ wt', data=mt).fit()
print(model2.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    mpg   R-squared:                       0.753
# Model:                            OLS   Adj. R-squared:                  0.745
# Method:                 Least Squares   F-statistic:                     91.38
# Date:                Mon, 10 Apr 2023   Prob (F-statistic):           1.29e-10
# Time:                        14:32:12   Log-Likelihood:                -80.015
# No. Observations:                  32   AIC:                             164.0
# Df Residuals:                      30   BIC:                             167.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     37.2851      1.878     19.858      0.000      33.450      41.120
# ...

# %%
pred=model2.predict()
pred
# Out:
# array([23.28261065, 21.9197704 , 24.88595212, 20.10265006, 18.90014396,
#        18.79325453, 18.20536265, 20.23626185, 20.45004071, 18.90014396,
#        18.90014396, 15.53312687, 17.3502472 , 17.08302362,  9.22665041,
#         8.29671236,  8.71892561, 25.52728871, 28.65380458, 27.47802083,
#        24.11100374, 18.47258623, 18.92686632, 16.76235533, 16.73563297,
#        26.94357367, 25.847957  , 29.19894068, 20.34315128, 22.48093991,
#        18.20536265, 22.4274952 ])

# %%
mt['prediction']=pred

# %%
mt.head(10)
# Out:
#     mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  carb  prediction
# 0  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4     4   23.282611
# 1  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4     4   21.919770
# 2  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4     1   24.885952
# 3  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3     1   20.102650
# 4  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3     2   18.900144
# 5  18.1    6  225.0  105  2.76  3.460  20.22   1   0     3     1   18.793255
# 6  14.3    8  360.0  245  3.21  3.570  15.84   0   0     3     4   18.205363
# 7  24.4    4  146.7   62  3.69  3.190  20.00   1   0     4     2   20.236262
# 8  22.8    4  140.8   95  3.92  3.150  22.90   1   0     4     2   20.450041
# 9  19.2    6  167.6  123  3.92  3.440  18.30   1   0     4     4   18.900144

# %%
plt.figure(figsize=(12,8))
plt.plot(mt['wt'],mt['mpg'],'o')
plt.plot(mt['wt'],pred,'r')
plt.xlabel("wt")
plt.ylabel("mpg")
plt.title("wt vs mpg")
plt.show()

# %%
model4=smapi.ols(formula='mpg ~ wt + disp + hp',data=mt).fit()
print(model4.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    mpg   R-squared:                       0.827
# Model:                            OLS   Adj. R-squared:                  0.808
# Method:                 Least Squares   F-statistic:                     44.57
# Date:                Mon, 10 Apr 2023   Prob (F-statistic):           8.65e-11
# Time:                        14:32:12   Log-Likelihood:                -74.321
# No. Observations:                  32   AIC:                             156.6
# Df Residuals:                      28   BIC:                             162.5
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     37.1055      2.111     17.579      0.000      32.782      41.429
# ...

# %%
lung=pd.read_csv('LungCap.csv')

# %%
lung.head(10)
# Out:
#    LungCap  Age  Height Smoke  Gender Caesarean
# 0    6.475    6    62.1    no    male        no
# 1   10.125   18    74.7   yes  female        no
# 2    9.550   16    69.7    no  female       yes
# 3   11.125   14    71.0    no    male        no
# 4    4.800    5    56.9    no    male        no
# 5    6.225   11    58.7    no  female        no
# 6    4.950    8    63.3    no    male       yes
# 7    7.325   11    70.4    no    male        no
# 8    8.875   15    70.5    no    male        no
# 9    6.800   11    59.2    no    male        no

# %%
lung.dtypes
# Out:
# LungCap      float64
# Age            int64
# Height       float64
# Smoke         object
# Gender        object
# Caesarean     object
# dtype: object

# %%
lung['Gender1']=lung['Gender'].map({'male':0,'female':1})

# %%
lung.head()
# Out:
#    LungCap  Age  Height Smoke  Gender Caesarean  Gender1
# 0    6.475    6    62.1    no    male        no        0
# 1   10.125   18    74.7   yes  female        no        1
# 2    9.550   16    69.7    no  female       yes        1
# 3   11.125   14    71.0    no    male        no        0
# 4    4.800    5    56.9    no    male        no        0

# %%
lung.dtypes
# Out:
# LungCap      float64
# Age            int64
# Height       float64
# Smoke         object
# Gender        object
# Caesarean     object
# Gender1        int64
# dtype: object

# %%
model00=smapi.ols(formula='Gender1 ~ LungCap',data=lung).fit()

print(model00.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                Gender1   R-squared:                       0.029
# Model:                            OLS   Adj. R-squared:                  0.027
# Method:                 Least Squares   F-statistic:                     21.47
# Date:                Mon, 10 Apr 2023   Prob (F-statistic):           4.26e-06
# Time:                        14:32:12   Log-Likelihood:                -515.53
# No. Observations:                 725   AIC:                             1035.
# Df Residuals:                     723   BIC:                             1044.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.7448      0.057     13.025      0.000       0.633       0.857
# ...

# %%
model010=smapi.ols(formula='LungCap~ Gender1 + Age + Height ',data=lung).fit()

print(model010.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                LungCap   R-squared:                       0.848
# Model:                            OLS   Adj. R-squared:                  0.848
# Method:                 Least Squares   F-statistic:                     1343.
# Date:                Mon, 10 Apr 2023   Prob (F-statistic):          1.27e-294
# Time:                        14:32:13   Log-Likelihood:                -1054.6
# No. Observations:                 725   AIC:                             2117.
# Df Residuals:                     721   BIC:                             2136.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    -10.8453      0.503    -21.575      0.000     -11.832      -9.858
# ...

# %%
mod=smapi.ols(formula=' disp ~ mpg + hp + carb',data=mt).fit()
print(mod.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                   disp   R-squared:                       0.837
# Model:                            OLS   Adj. R-squared:                  0.820
# Method:                 Least Squares   F-statistic:                     47.99
# Date:                Mon, 10 Apr 2023   Prob (F-statistic):           3.67e-11
# Time:                        14:32:13   Log-Likelihood:                -170.09
# No. Observations:                  32   AIC:                             348.2
# Df Residuals:                      28   BIC:                             354.0
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    371.7898     78.176      4.756      0.000     211.653     531.927
# ...

# %%
preeee=mod.predict()
preeee
# Out:
# array([138.28995606, 138.28995606, 192.24408914, 228.8108504 ,
#        306.62737304, 260.45050564, 378.2161135 , 104.75119074,
#        162.96832135, 174.58388053, 190.57423114, 307.25259826,
#        296.97308715, 320.95861307, 374.34557775, 386.44934872,
#        355.49178544,  49.91578905,  24.11734572,  31.57289344,
#        211.93378023, 312.91731844, 316.34382214, 389.6377925 ,
#        300.91653353, 108.16635198, 121.57744014,  97.95034864,
#        384.08075983, 168.41960611, 352.36878899, 195.90395132])

# %%
mt['ppp']=preeee

# %%
mt
# Out:
#      mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  carb  prediction  \
# 0   21.0    6  160.0  110  3.90  2.620  16.46   0   1     4     4   23.282611
# 1   21.0    6  160.0  110  3.90  2.875  17.02   0   1     4     4   21.919770
# 2   22.8    4  108.0   93  3.85  2.320  18.61   1   1     4     1   24.885952
# 3   21.4    6  258.0  110  3.08  3.215  19.44   1   0     3     1   20.102650
# 4   18.7    8  360.0  175  3.15  3.440  17.02   0   0     3     2   18.900144
# 5   18.1    6  225.0  105  2.76  3.460  20.22   1   0     3     1   18.793255
# 6   14.3    8  360.0  245  3.21  3.570  15.84   0   0     3     4   18.205363
# 7   24.4    4  146.7   62  3.69  3.190  20.00   1   0     4     2   20.236262
# 8   22.8    4  140.8   95  3.92  3.150  22.90   1   0     4     2   20.450041
# 9   19.2    6  167.6  123  3.92  3.440  18.30   1   0     4     4   18.900144
# 10  17.8    6  167.6  123  3.92  3.440  18.90   1   0     4     4   18.900144
# ...

# %%
import statsmodels.api as sm
fig=plt.figure(figsize=(12,8))
sm.graphics.plot_regress_exog(model1,'disp', fig=fig)

# %%
mt.corr()
# Out:
#                  mpg       cyl      disp        hp      drat        wt  \
# mpg         1.000000 -0.852162 -0.847551 -0.776168  0.681172 -0.867659
# cyl        -0.852162  1.000000  0.902033  0.832447 -0.699938  0.782496
# disp       -0.847551  0.902033  1.000000  0.790949 -0.710214  0.887980
# hp         -0.776168  0.832447  0.790949  1.000000 -0.448759  0.658748
# drat        0.681172 -0.699938 -0.710214 -0.448759  1.000000 -0.712441
# wt         -0.867659  0.782496  0.887980  0.658748 -0.712441  1.000000
# qsec        0.418684 -0.591242 -0.433698 -0.708223  0.091205 -0.174716
# vs          0.664039 -0.810812 -0.710416 -0.723097  0.440278 -0.554916
# am          0.599832 -0.522607 -0.591227 -0.243204  0.712711 -0.692495
# gear        0.480285 -0.492687 -0.555569 -0.125704  0.699610 -0.583287
# carb       -0.550925  0.526988  0.394977  0.749812 -0.090790  0.427606
# prediction  0.867659 -0.782496 -0.887980 -0.658748  0.712441 -1.000000
# ...
